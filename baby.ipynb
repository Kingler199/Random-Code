# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.DataFrame(pd.read_csv('US_Baby_Names_right.csv'))
pd.set_option('display.max_rows', 77)

# %%
df.head(5)
# Out:
#    Unnamed: 0     Id     Name  Year Gender State  Count
# 0       11349  11350     Emma  2004      F    AK     62
# 1       11350  11351  Madison  2004      F    AK     48
# 2       11351  11352   Hannah  2004      F    AK     46
# 3       11352  11353    Grace  2004      F    AK     44
# 4       11353  11354    Emily  2004      F    AK     41

# %%
male = df.loc[(df['Gender']=='M') & (df['Year']==2009), ['Name']]
female = (df.loc[df['Gender']=='M']) &

# %%
top_male_2009 = male.value_counts().reset_index().rename(columns={0:'Name Counts'})

top_male_2009[top_male_2009['Name Counts']==51] #top male names
# Out:
#            Name  Name Counts
# 0        Joseph           51
# 1           Ian           51
# 2          Noah           51
# 3         Caleb           51
# 4         Ayden           51
# 5      Nicholas           51
# 6         Isaac           51
# 7     Nathaniel           51
# 8          Ryan           51
# 9        Nathan           51
# 10        Aiden           51
# 11       Justin           51
# 12      Tristan           51
# 13         John           51
# 14    Christian           51
# 15       Landon           51
# 16      William           51
# 17       Andrew           51
# 18        Wyatt           51
# 19       Carter           51
# 20        Aidan           51
# 21        Jacob           51
# 22      Vincent           51
# 23       Isaiah           51
# 24      Gabriel           51
# 25     Jeremiah           51
# 26         Evan           51
# 27        Tyler           51
# 28        Gavin           51
# 29      Dominic           51
# 30        Riley           51
# ...

# %%
#wew = df[['Name', 'Gender','Year']].value_counts().reset_index()
grouped = df[df['Year']==2009].groupby('Gender')['Name'].value_counts()['F'].reset_index(name='Name Count')

# %%
grouped[grouped['Name Count']==51]
# Out:
#          Name  Name Count
# 0     Abigail          51
# 1     Addison          51
# 2      Alexis          51
# 3      Alyssa          51
# 4      Amelia          51
# 5        Anna          51
# 6     Arianna          51
# 7      Aubrey          51
# 8      Audrey          51
# 9         Ava          51
# 10      Avery          51
# 11     Bailey          51
# 12      Bella          51
# 13    Brianna          51
# 14     Brooke          51
# 15   Brooklyn          51
# 16      Chloe          51
# 17     Claire          51
# 18  Elizabeth          51
# 19       Ella          51
# 20      Emily          51
# 21       Emma          51
# 22        Eva          51
# 23     Evelyn          51
# 24      Faith          51
# 25      Grace          51
# 26     Hailey          51
# 27     Hannah          51
# 28   Isabella          51
# 29     Kaylee          51
# 30       Leah          51
# 31    Lillian          51
# 32       Lily          51
# 33    Madison          51
# ...
